# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget http://www.statmt.org/wmt13/training-parallel-europarl-v7.tgz -P /content/drive/My\ Drive/Machine_Translation_Dataset/En_Fr/
# Out:
# --2020-07-01 17:41:04--  http://www.statmt.org/wmt13/training-parallel-europarl-v7.tgz
# Resolving www.statmt.org (www.statmt.org)... 129.215.197.184
# Connecting to www.statmt.org (www.statmt.org)|129.215.197.184|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 657632379 (627M) [application/x-gzip]
# Saving to: ‘/content/drive/My Drive/Machine_Translation_Dataset/En_Fr/training-parallel-europarl-v7.tgz’
#
# training-parallel-e 100%[===================>] 627.17M   183KB/s    in 49m 10s
#
# 2020-07-01 18:30:15 (218 KB/s) - ‘/content/drive/My Drive/Machine_Translation_Dataset/En_Fr/training-parallel-europarl-v7.tgz’ saved [657632379/657632379]

# %%
# !wget http://www.statmt.org/wmt13/training-parallel-commoncrawl.tgz -P /content/drive/My\ Drive/Machine_Translation_Dataset/En_Fr/
# Out:
# --2020-07-01 18:34:03--  http://www.statmt.org/wmt13/training-parallel-commoncrawl.tgz
# Resolving www.statmt.org (www.statmt.org)... 129.215.197.184
# Connecting to www.statmt.org (www.statmt.org)|129.215.197.184|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 918311367 (876M) [application/x-gzip]
# Saving to: ‘/content/drive/My Drive/Machine_Translation_Dataset/En_Fr/training-parallel-commoncrawl.tgz’
#
# training-parallel-c 100%[===================>] 875.77M   275KB/s    in 59m 53s
#
# 2020-07-01 19:33:57 (250 KB/s) - ‘/content/drive/My Drive/Machine_Translation_Dataset/En_Fr/training-parallel-commoncrawl.tgz’ saved [918311367/918311367]

# %%
# !wget http://www.statmt.org/wmt13/training-parallel-un.tgz -P /content/drive/My\ Drive/Machine_Translation_Dataset/En_Fr/
# Out:
# --2020-10-27 18:06:59--  http://www.statmt.org/wmt13/training-parallel-un.tgz
# Resolving www.statmt.org (www.statmt.org)... 129.215.197.184
# Connecting to www.statmt.org (www.statmt.org)|129.215.197.184|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2365634246 (2.2G) [application/x-gzip]
# Saving to: ‘/content/drive/My Drive/Machine_Translation_Dataset/En_Fr/training-parallel-un.tgz’
#
# training-parallel-u 100%[===================>]   2.20G  1.18MB/s    in 45m 10s
#
# 2020-10-27 18:52:10 (852 KB/s) - ‘/content/drive/My Drive/Machine_Translation_Dataset/En_Fr/training-parallel-un.tgz’ saved [2365634246/2365634246]

# %%
# !wget http://www.statmt.org/wmt14/training-parallel-nc-v9.tgz -P /content/drive/My\ Drive/Machine_Translation_Dataset/En_Fr/
# Out:
# --2020-10-27 19:21:14--  http://www.statmt.org/wmt14/training-parallel-nc-v9.tgz
# Resolving www.statmt.org (www.statmt.org)... 129.215.197.184
# Connecting to www.statmt.org (www.statmt.org)|129.215.197.184|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 80418416 (77M) [application/x-gzip]
# Saving to: ‘/content/drive/My Drive/Machine_Translation_Dataset/En_Fr/training-parallel-nc-v9.tgz.1’
#
#      training-paral   2%[                    ]   2.00M  1.40MB/s               ^C

# %%
# !wget http://www.statmt.org/wmt10/training-giga-fren.tar -P /content/drive/My\ Drive/Machine_Translation_Dataset/En_Fr/
# Out:
# --2020-10-27 18:53:43--  http://www.statmt.org/wmt10/training-giga-fren.tar
# Resolving www.statmt.org (www.statmt.org)... 129.215.197.184
# Connecting to www.statmt.org (www.statmt.org)|129.215.197.184|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2595102720 (2.4G) [application/x-tar]
# Saving to: ‘/content/drive/My Drive/Machine_Translation_Dataset/En_Fr/training-giga-fren.tar’
#
# training-giga-fren. 100%[===================>]   2.42G  2.28MB/s    in 27m 15s
#
# 2020-10-27 19:20:58 (1.51 MB/s) - ‘/content/drive/My Drive/Machine_Translation_Dataset/En_Fr/training-giga-fren.tar’ saved [2595102720/2595102720]

# %%
# !wget http://www.statmt.org/wmt14/dev.tgz -P /content/drive/My\ Drive/Machine_Translation_Dataset/En_Fr/
# Out:
# --2020-10-27 19:20:58--  http://www.statmt.org/wmt14/dev.tgz
# Resolving www.statmt.org (www.statmt.org)... 129.215.197.184
# Connecting to www.statmt.org (www.statmt.org)|129.215.197.184|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17742707 (17M) [application/x-gzip]
# Saving to: ‘/content/drive/My Drive/Machine_Translation_Dataset/En_Fr/dev.tgz’
#
# dev.tgz             100%[===================>]  16.92M  2.31MB/s    in 7.7s
#
# 2020-10-27 19:21:06 (2.21 MB/s) - ‘/content/drive/My Drive/Machine_Translation_Dataset/En_Fr/dev.tgz’ saved [17742707/17742707]

# %%
# !wget http://www.statmt.org/wmt14/test.tgz -P /content/drive/My\ Drive/Machine_Translation_Dataset/En_Fr/
# Out:
# --2020-10-27 19:21:06--  http://www.statmt.org/wmt14/test.tgz
# Resolving www.statmt.org (www.statmt.org)... 129.215.197.184
# Connecting to www.statmt.org (www.statmt.org)|129.215.197.184|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5352747 (5.1M) [application/x-gzip]
# Saving to: ‘/content/drive/My Drive/Machine_Translation_Dataset/En_Fr/test.tgz’
#
# test.tgz            100%[===================>]   5.10M  1.09MB/s    in 4.7s
#
# 2020-10-27 19:21:11 (1.09 MB/s) - ‘/content/drive/My Drive/Machine_Translation_Dataset/En_Fr/test.tgz’ saved [5352747/5352747]

# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 69, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 52316 (delta 30), reused 46 (delta 10), pack-reused 52247
# Receiving objects: 100% (52316/52316), 569.29 MiB | 21.71 MiB/s, done.
# Resolving deltas: 100% (35705/35705), done.

# %%
# !rm /content/models/official/nlp/transformer/utils/tokenizer.py

# %%
# !mv /content/tokenizer.py /content/models/official/nlp/transformer/utils

# %%
# !rm /content/models/official/nlp/transformer/data_download.py

# %%
# !mv /content/data_download.py /content/models/official/nlp/transformer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.environ['PYTHONPATH'] += ":/content/models"

import sys
sys.path.append("/content/models")

# %%
# !python3 /content/models/official/nlp/transformer/data_download.py --data_dir=/content/drive/MyDrive/Machine_Translation_Dataset/WMT_14_TfRecords_En_Fr --raw_dir=/content/drive/MyDrive/Machine_Translation_Dataset/En_Fr --search
# Out:
# 2021-02-25 05:28:39.818368: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# I0225 05:28:42.954990 140456718899072 data_download.py:385] Step 1/5: Downloading test data
# I0225 05:28:44.471117 140456718899072 data_download.py:204] Already downloaded and extracted http://www.statmt.org/wmt14/test.tgz.
# I0225 05:28:44.471554 140456718899072 data_download.py:389] Step 2/5: Downloading data from source
# I0225 05:28:45.389743 140456718899072 data_download.py:204] Already downloaded and extracted http://www.statmt.org/wmt13/training-parallel-europarl-v7.tgz.
# I0225 05:28:45.391072 140456718899072 data_download.py:204] Already downloaded and extracted http://www.statmt.org/wmt13/training-parallel-commoncrawl.tgz.
# I0225 05:28:45.742680 140456718899072 data_download.py:204] Already downloaded and extracted http://www.statmt.org/wmt13/training-parallel-un.tgz.
# ...

# %%
from google.colab import auth
auth.authenticate_user()

project_id = 'PROJECT_NAME'
# !gcloud config set project {project_id}
# !gsutil ls
# Out:
# Updated property [core/project].
# gs://sagcn/

# %%
bucket_name = 'BUCKET_NAME'

# !gsutil -m cp -r /content/drive/MyDrive/Machine_Translation_Dataset/WMT_14_TfRecords_En_Fr gs://{bucket_name}/WMT_14_TfRecords_En-Fr
# Out:
# Copying file:///content/drive/MyDrive/Machine_Translation_Dataset/WMT_14_TfRecords_En_Fr/test.tgz [Content-Type=application/x-tar]...
# Copying file:///content/drive/MyDrive/Machine_Translation_Dataset/WMT_14_TfRecords_En_Fr/wmt32k-train-00005-of-00100.incomplete [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/Machine_Translation_Dataset/WMT_14_TfRecords_En_Fr/vocab.enfr.32000 [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/Machine_Translation_Dataset/WMT_14_TfRecords_En_Fr/wmt32k-train-00001-of-00100.incomplete [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/Machine_Translation_Dataset/WMT_14_TfRecords_En_Fr/wmt32k-train-00007-of-00100.incomplete [Content-Type=application/octet-stream]...
# Copying file:///content/drive/MyDrive/Machine_Translation_Dataset/WMT_14_TfRecords_En_Fr/wmt32k-train-00002-of-00100.incomplete [Content-Type=application/octet-stream]...
# ...
